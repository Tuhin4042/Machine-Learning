# %% [markdown]
# ## Pandas Built-in Data Visualization
#
# * Histograms
# * Area plot
# * Bar plots
# * Line plots
# * Scatter plots
# * BoxPlots
# * Pie Plot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Generating `df1`

# %%
dates = pd.date_range('1/1/2000', periods=500)
dates
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2001-05-05', '2001-05-06', '2001-05-07', '2001-05-08',
#                '2001-05-09', '2001-05-10', '2001-05-11', '2001-05-12',
#                '2001-05-13', '2001-05-14'],
#               dtype='datetime64[ns]', length=500, freq='D')

# %%
dates
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2001-05-05', '2001-05-06', '2001-05-07', '2001-05-08',
#                '2001-05-09', '2001-05-10', '2001-05-11', '2001-05-12',
#                '2001-05-13', '2001-05-14'],
#               dtype='datetime64[ns]', length=500, freq='D')

# %%
# Let's use numpy's randn for "standard normal" distribution
data1 = np.random.randn(500,3) # (500,3) to tell the shape we want
data1
# Out:
# array([[-0.57067797, -2.22152318, -1.87780599],
#        [ 1.43167177,  0.67588831, -0.37479124],
#        [ 0.71415807,  0.00737573, -0.17861201],
#        ...,
#        [ 0.11497393, -1.89893523,  0.54689855],
#        [ 1.08658223,  0.36331553,  1.79830952],
#        [-1.59501991, -0.56272566,  0.84533415]])

# %%
# randn(1000,4) 1000 by 4 2D array    
df1 = pd.DataFrame(data = data1, index=dates, columns=['A', 'B', 'C'])

# %%
df1
# Out:
#                    A         B         C
# 2000-01-01 -0.570678 -2.221523 -1.877806
# 2000-01-02  1.431672  0.675888 -0.374791
# 2000-01-03  0.714158  0.007376 -0.178612
# 2000-01-04 -0.586465  0.893860  2.300553
# 2000-01-05 -0.055592  0.211474  1.211537
# ...              ...       ...       ...
# 2001-05-10  0.724051 -0.263539 -0.173820
# 2001-05-11 -0.364793  0.935538  0.610620
# 2001-05-12  0.114974 -1.898935  0.546899
# 2001-05-13  1.086582  0.363316  1.798310
# 2001-05-14 -1.595020 -0.562726  0.845334
#
# [500 rows x 3 columns]

# %% [markdown]
# Let's add col_D as a column to df1

# %%
# Let's generate a series using rand()
df1['D'] = np.random.rand(500)

# %%
df1
# Out:
#                    A         B         C         D
# 2000-01-01 -0.570678 -2.221523 -1.877806  0.333447
# 2000-01-02  1.431672  0.675888 -0.374791  0.417524
# 2000-01-03  0.714158  0.007376 -0.178612  0.962734
# 2000-01-04 -0.586465  0.893860  2.300553  0.040428
# 2000-01-05 -0.055592  0.211474  1.211537  0.001822
# ...              ...       ...       ...       ...
# 2001-05-10  0.724051 -0.263539 -0.173820  0.213643
# 2001-05-11 -0.364793  0.935538  0.610620  0.325385
# 2001-05-12  0.114974 -1.898935  0.546899  0.856129
# 2001-05-13  1.086582  0.363316  1.798310  0.485361
# 2001-05-14 -1.595020 -0.562726  0.845334  0.744062
#
# [500 rows x 4 columns]

# %% [markdown]
# ### Generating `df2`

# %%
# rand(20,3) 20 by 3 2D array
data2 = np.random.rand(20,3)
col = ['X', 'Y', 'Z']
ind = np.arange(1,21)
df2 = pd.DataFrame(data = data2,index= ind,columns=col)

# %%
df2
# Out:
#            X         Y         Z
# 1   0.493000  0.237217  0.769661
# 2   0.156219  0.866633  0.355760
# 3   0.668322  0.448947  0.894326
# 4   0.284949  0.202975  0.676672
# 5   0.337163  0.549347  0.866409
# 6   0.985305  0.489774  0.489912
# 7   0.861875  0.287029  0.077025
# 8   0.365357  0.564948  0.909025
# 9   0.093976  0.863598  0.166828
# 10  0.442179  0.780549  0.898992
# 11  0.117625  0.791021  0.052971
# 12  0.614222  0.213413  0.560889
# 13  0.177820  0.157207  0.744986
# 14  0.082755  0.533953  0.127929
# 15  0.008015  0.377808  0.494474
# 16  0.580525  0.048492  0.953665
# 17  0.149273  0.073006  0.997069
# 18  0.954332  0.257827  0.886881
# 19  0.392675  0.628851  0.501219
# 20  0.753589  0.934772  0.325205

# %% [markdown]
# Let's start with simple histogram plot, we can get the hist plot in two ways!
# * `DataFrame.hist()`
# * `DataFrame.plot(kind = 'hist')`
#
# Let's try both one-by-one first, later on, we will talk about style sheet and discuss the range of plotting options in details!

# %%
df1['A'].hist(bins=30)    # Note that it is using matplotlib under the hood
# Out:
# <AxesSubplot:>

# %%
# we can also plot using kind
df1['A'].plot(kind='hist',bins=30)
# For whole dataset
#df1.plot(kind='hist',bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## Style Sheets
#
# Matplotlib has [style sheets](http://matplotlib.org/gallery.html#style_sheets). We can use this to make our plots look a little nicer. These style sheets include `plot_bmh`,`plot_fivethirtyeight`,`plot_ggplot` and more. They basically create a set of style rules that our plots follow. Its good to use them because they make all our plots to have the same look and feel more professional. <br>

# %%
plt.figure(figsize=(5,4)) #figure size
plt.style.use('ggplot')
df1['A'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(5,4)) #figure size
plt.style.use('bmh')
df1['A'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
# we can use dark_background
plt.figure(figsize=(5,4)) #figure size
plt.style.use('dark_background')
df1['A'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
# another example
plt.style.use('fivethirtyeight')
df1['A'].plot(kind='hist',bins=50,figsize=(8,4))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2['X'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Plot Types
#
# There are several plot types built-in to pandas, most of them are statistical plots by nature:
#
# * `df.plot.area`
# * `df.plot.bar`
# * `df.plot.barh`
# * `df.plot.hist`
# * `df.plot.line`
# * `df.plot.scatter`
# * `df.plot.box`
# * `df.plot.pie`
#
# We can also just call `df.plot(kind='hist')` or replace that kind argument with any of the key terms shown in the list above (e.g. `'box','barh'`, etc..)<br>

# %% [markdown]
# ### Area plot

# %%
df2.head()
# Out:
#           X         Y         Z
# 1  0.493000  0.237217  0.769661
# 2  0.156219  0.866633  0.355760
# 3  0.668322  0.448947  0.894326
# 4  0.284949  0.202975  0.676672
# 5  0.337163  0.549347  0.866409

# %%
plt.style.use('dark_background')
df2['X'].plot(kind='area',alpha=0.5)
#df2.plot(kind = 'area', alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
df2.plot.area(alpha=0.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Bar plots

# %%
df2.head()
# Out:
#           X         Y         Z
# 1  0.493000  0.237217  0.769661
# 2  0.156219  0.866633  0.355760
# 3  0.668322  0.448947  0.894326
# 4  0.284949  0.202975  0.676672
# 5  0.337163  0.549347  0.866409

# %%
df2.plot(kind = "bar",figsize = (7,5))
# Out:
# <AxesSubplot:>

# %%
# Horizontal bars
df2.plot.barh(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
df2
# Out:
#            X         Y         Z
# 1   0.493000  0.237217  0.769661
# 2   0.156219  0.866633  0.355760
# 3   0.668322  0.448947  0.894326
# 4   0.284949  0.202975  0.676672
# 5   0.337163  0.549347  0.866409
# 6   0.985305  0.489774  0.489912
# 7   0.861875  0.287029  0.077025
# 8   0.365357  0.564948  0.909025
# 9   0.093976  0.863598  0.166828
# 10  0.442179  0.780549  0.898992
# 11  0.117625  0.791021  0.052971
# 12  0.614222  0.213413  0.560889
# 13  0.177820  0.157207  0.744986
# 14  0.082755  0.533953  0.127929
# 15  0.008015  0.377808  0.494474
# 16  0.580525  0.048492  0.953665
# 17  0.149273  0.073006  0.997069
# 18  0.954332  0.257827  0.886881
# 19  0.392675  0.628851  0.501219
# 20  0.753589  0.934772  0.325205

# %%
# we can stack them on top of each other 
df2.plot.bar(stacked=True, figsize=(6,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Histogram

# %% [markdown]
# A histogram can be stacked using `stacked=True`. This is not what we use often but it is good to know!

# %%
df1.plot.hist(stacked = True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# We can pass other keywords supported by `matplotlib hist`. For example, `horizontal` and `cumulative` histograms can be drawn by `orientation='horizontal`' and `cumulative=True`.<br>

# %%
df1.plot.hist(orientation='horizontal',alpha = 0.5)
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %% [markdown]
# ### Line plots

# %%
gas = pd.read_csv('gas_prices.csv')
gas.head()
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %%
gas['USA'].plot()
# Out:
# <AxesSubplot:>

# %%
plt.subplots(figsize=(15,5))
#gas['USA'].plot()
plt.plot(gas['Year'], gas['USA'])

# %%
gas.Year.min(), gas.Year.max()
# Out:
# (1990, 2008)

# %%
gas.Year[::3].tolist()
# Out:
# [1990, 1993, 1996, 1999, 2002, 2005, 2008]

# %%
plt.subplots(figsize=(7,5))
plt.plot(gas['Year'], gas['USA'])
plt.xticks(gas.Year[::3].tolist())
# Out:
# ([<matplotlib.axis.XTick at 0x253bcf13f70>,
#   <matplotlib.axis.XTick at 0x253bcf13f40>,
#   <matplotlib.axis.XTick at 0x253bcf13670>,
#   <matplotlib.axis.XTick at 0x253bd2b58e0>,
#   <matplotlib.axis.XTick at 0x253bd2be070>,
#   <matplotlib.axis.XTick at 0x253bd2be7c0>,
#   <matplotlib.axis.XTick at 0x253bd2bef10>],
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.style.use('dark_background')
#plt.style.use('fivethirtyeight')

# %%
plt.figure(figsize=(9,5))

plt.title('Gas Prices over Time (in USD)', fontdict={'fontweight':'bold', 'fontsize': 18, 'color':'r'})

plt.plot(gas.Year, gas.USA, 'b--', label='USA')
plt.plot(gas.Year, gas['Canada'], 'r.-', label='Canada')
plt.plot(gas.Year, gas['South Korea'], 'g.-', label='South Korea')
plt.plot(gas.Year, gas.Australia, 'y.-', label='Australia')

plt.xticks(gas.Year[::3].tolist()) #[1990, 1993, 1996, 1999, 2002, 2005, 2008]

# #plt.yticks([0, 2, 4, 6, 8]) 
# #plt.xticks([1990, 1993, 1996, 1999, 2002, 2005, 2008]) 

plt.xlabel('Year',fontdict={"fontsize":10,"fontweight":'bold'})
plt.ylabel('US Dollars',fontdict={"fontsize":10,"fontweight":'bold'})

plt.legend(loc=2) #default loc=2

plt.savefig('Gas_price_figure.png', dpi=300)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01 -0.570678 -2.221523 -1.877806  0.333447
# 2000-01-02  1.431672  0.675888 -0.374791  0.417524
# 2000-01-03  0.714158  0.007376 -0.178612  0.962734
# 2000-01-04 -0.586465  0.893860  2.300553  0.040428
# 2000-01-05 -0.055592  0.211474  1.211537  0.001822

# %%
df1.plot.scatter(x='A', y='B',figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.line('A', 'B',figsize=(10,5),lw=.3)
# Out:
# <AxesSubplot:xlabel='A'>

# %% [markdown]
# ### Scatter plots
# Scatter plot can be drawn by using the `DataFrame.plot.scatter()` method. Scatter plot requires numeric columns for the x and y axes. These can be specified by the x and y keywords.<br>

# %%
plt.style.use('bmh')
df1.plot.scatter(x='A', y='B', color='Red', figsize=(12,3))
plt.xticks(np.arange(-3,4))
plt.xlabel("X label")
plt.ylabel("y label")
# Out:
# Text(0, 0.5, 'y label')

# %%
plt.style.use("dark_background")
df1.plot.scatter(x='A',y='B', c='D', cmap='coolwarm', figsize=(12,3))
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %% [markdown]
# We can use **`s`** to indicate size of the bubble based on another column. <br>
# **`s`** parameter needs to be an array, not just the name of a column:

# %%
df1.plot.hexbin(x='A',y='B',gridsize=30, cmap='Oranges',  figsize=(12,3))
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2.head()
# Out:
#           X         Y         Z
# 1  0.493000  0.237217  0.769661
# 2  0.156219  0.866633  0.355760
# 3  0.668322  0.448947  0.894326
# 4  0.284949  0.202975  0.676672
# 5  0.337163  0.549347  0.866409

# %%
df2.X.max(),df2.Y.max(),df2.Z.max()
# Out:
# (0.9853052796514202, 0.9347723194005032, 0.9970690918116214)

# %% [markdown]
# ## Pie Plot
# We can create a pie plot with  `Series.plot.pie()` or `DataFrame.plot.pie()`. If your data includes any NaN, they will be automatically filled with 0. A ValueError will be raised if there are any negative values in your data.<br>
#
# We need to specify a target column by the y argument. When y is specified, pie plot of selected column will be drawn.

# %%
fifa = pd.read_csv('fifa_data.csv')
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club  ... Composure Marking StandingTackle  SlidingTackle  \
# 0         FC Barcelona  ...      96.0    33.0           28.0           26.0
# 1             Juventus  ...      95.0    28.0           31.0           23.0
# 2  Paris Saint-Germain  ...      94.0    27.0           24.0           33.0
# 3    Manchester United  ...      68.0    15.0           21.0           13.0
# 4      Manchester City  ...      88.0    68.0           58.0           51.0
#
#   GKDiving  GKHandling  GKKicking  GKPositioning GKReflexes Release Clause
# 0      6.0        11.0       15.0           14.0        8.0        €226.5M
# 1      7.0        11.0       15.0           14.0       11.0        €127.1M
# 2      9.0         9.0       15.0           15.0       11.0        €228.1M
# 3     90.0        85.0       87.0           88.0       94.0        €138.6M
# 4     15.0        13.0        5.0           10.0       13.0        €196.4M
#
# [5 rows x 89 columns]

# %%
fifa['Weight']
# Out:
# 0        159lbs
# 1        183lbs
# 2        150lbs
# 3        168lbs
# 4        154lbs
#           ...
# 18202    134lbs
# 18203    170lbs
# 18204    148lbs
# 18205    154lbs
# 18206    176lbs
# Name: Weight, Length: 18207, dtype: object

# %%
def stripdata(x):
    if type(x)==str:
        return int(x.strip('lbs'))
    else:
        return x
    
fifa['Weight'] = fifa['Weight'].apply(stripdata)

# %%
fifa['Weight']
# Out:
# 0        159.0
# 1        183.0
# 2        150.0
# 3        168.0
# 4        154.0
#          ...
# 18202    134.0
# 18203    170.0
# 18204    148.0
# 18205    154.0
# 18206    176.0
# Name: Weight, Length: 18207, dtype: float64

# %%
light = fifa[fifa.Weight < 125].count()[0]
light
# Out:
# 41

# %%
plt.figure(figsize=(15,10), dpi=100)


light = fifa[fifa.Weight < 125].count()[0]
light_medium = fifa[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
medium = fifa[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()[0]
medium_heavy = fifa[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()[0]
heavy = fifa[fifa.Weight >= 200].count()[0]


weights = [light,light_medium, medium, medium_heavy, heavy]
label = ['under 125', '125-150', '150-175', '175-200', 'over 200']

print(weights)

explode = [.4,.2,0,0,.4]

plt.pie(weights, labels=label, explode=explode,  autopct='%.2f %%',  pctdistance=0.5)

#plt.pie(weights, labels=label, autopct='%.2f %%',  pctdistance=0.7)

plt.legend(title="Weight Range",loc=2)
plt.show()
# Out:
# [41, 2290, 10876, 4583, 369]

# %%
import plotly.graph_objects as pgo

# %%
fig = pgo.Figure(data=[pgo.Pie(values=weights, labels = label, hole = 0.5)])

fig.update_layout(
    title='Draw a Pie Chart',
    title_x=0.5,
    title_font=dict(size=24, family='Arial, bold', color='darkblue'),
    
    legend=dict(
        title=dict(text='Weight Range', font=dict(size=14, family='Arial, bold', color='green')),
        
        traceorder='normal',
        font=dict(
            family='Arial, bold',
            size=12,
            color='black'
        ),
    )
)

fig.show()
# Out:
# <div>                            <div id="980800fc-8b95-4989-b9e1-142867ab646d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("980800fc-8b95-4989-b9e1-142867ab646d")) {                    Plotly.newPlot(                        "980800fc-8b95-4989-b9e1-142867ab646d",                        [{"hole":0.5,"labels":["under 125","125-150","150-175","175-200","over 200"],"values":[41,2290,10876,4583,369],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks" ...
#
# var g
